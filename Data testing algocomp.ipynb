# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np
from chart_data import *

# %%
amplitude_a = np.asarray(amplitude_a)
x = np.linspace(0, len(amplitude_a), len(amplitude_a))
plt.figure(figsize=(20,10))
plt.title("Chord A Amplitude")
plt.plot(x, amplitude_a)

# %%
amplitude_b = np.asarray(amplitude_b)
x = np.linspace(0, len(amplitude_b), len(amplitude_b))
plt.figure(figsize=(20,10))
plt.title("Chord B Amplitude")
plt.plot(x, amplitude_b)

# %%
arp_period_a = np.asarray(arp_period_a)
x = np.linspace(0, len(arp_period_a), len(arp_period_a))
plt.figure(figsize=(20,10))
plt.title("Chord A Arpeggio Period")
plt.plot(x, arp_period_a)

# %%
arp_period_b = np.asarray(arp_period_b)
x = np.linspace(0, len(arp_period_b), len(arp_period_b))
plt.figure(figsize=(20,10))
plt.title("Chord B Arpeggio Period")
plt.plot(x, arp_period_b)
